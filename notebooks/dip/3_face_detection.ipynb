# %%
import numpy as np
import cv2
# %matplotlib inline
import matplotlib.pyplot as plt
import time

# %% [markdown]
# # Face detection

# %%
# Create the haar cascade
cascPath = 'notebooks/dip/detect/haarcascade_frontalface_alt.xml'
# cascPath = 'detect/haarcascade_frontalface_default.xml'
faceCascade = cv2.CascadeClassifier(cascPath)

# %%
# Read the image
img = cv2.imread('notebooks/dip/images/ioi2.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-d6d7d2f1617a> in <module>
#       1 # Read the image
#       2 img = cv2.imread('notebooks/dip/images/ioi2.jpg')
# ----> 3 plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#
# error: OpenCV(3.4.5) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:181: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
def detect_faces_show(fpath):
    img = cv2.imread(fpath)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    # Detect faces in the image
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.2,
        minNeighbors=5,
        minSize=(30, 30),
        flags = cv2.CASCADE_SCALE_IMAGE
    )
    print("Found %d faces!" % len(faces))

    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 4)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
detect_faces_show('images/ioi.jpg')
# Out:
# Found 5 faces!

# %%
detect_faces_show('notebooks/dip/images/ioi2.jpg')
# Out:
# Found 11 faces!
